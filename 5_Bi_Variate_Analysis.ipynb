# %% [markdown]
# <a href="https://colab.research.google.com/github/datagrad/Learning-Python/blob/main/5_Bi_Variate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bi-Variate Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datagrad/Learning-Python/main/Marks%20Data.csv')
df
# Out:
#          Roll_Code  Math  English  Science  Total  Year
# 0      2022_A10001    22       60       61    143  2022
# 1      2022_B10002     6       20       31     57  2022
# 2      2022_A10003    19       40       30     89  2022
# 3      2022_B10004     4       39       75    118  2022
# 4      2021_C10005    66       30       24    120  2021
# ...            ...   ...      ...      ...    ...   ...
# 12289  2018_C34247    82       48       37    167  2018
# 12290  2018_A34248    83       90       47    220  2018
# 12291  2018_A34249    82       86       73    241  2018
# 12292  2018_B34250    90       70       64    224  2018
# 12293  2018_A34251    87       63       44    194  2018
#
# [12294 rows x 6 columns]

# %% [markdown]
# # 1. Covariance

# %%
np.cov(df['Total'], df['Math'])
# Out:
# array([[1839.37717936,  877.20629132],
#        [ 877.20629132,  749.94292543]])

# %%
df.cov()
# Out:
#                Math     English     Science        Total      Year
# Math     749.942925  143.342602  -16.079236   877.206291 -5.084448
# English  143.342602  503.367683   -9.138676   637.571609 -2.468648
# Science  -16.079236   -9.138676  349.817192   324.599279  0.377018
# Total    877.206291  637.571609  324.599279  1839.377179 -7.176078
# Year      -5.084448   -2.468648    0.377018    -7.176078  2.039891

# %% [markdown]
# # 2. Correlation

# %%
np.corrcoef(df['Total'], df['Math'])
# Out:
# array([[1.        , 0.74688242],
#        [0.74688242, 1.        ]])

# %%
sns.scatterplot(x='Math', y='English', data=df)

# %%
df.corr()
# Out:
#              Math   English   Science     Total      Year
# Math     1.000000  0.233302 -0.031393  0.746882 -0.129995
# English  0.233302  1.000000 -0.021778  0.662599 -0.077039
# Science -0.031393 -0.021778  1.000000  0.404661  0.014114
# Total    0.746882  0.662599  0.404661  1.000000 -0.117152
# Year    -0.129995 -0.077039  0.014114 -0.117152  1.000000

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(10, 9))

sns.heatmap(corrmat, ax=ax, cmap="YlGnBu", linewidths=0.1)
